# %%
import time
import random as rd

# %%
def attack(power,name):
    attack_choice = rd.randint(1, 5)
        
    if attack_choice == 1:
        power = 10
        name = 'Kick'
    if attack_choice == 2:
        power = 5
        name = 'Puch'
    if attack_choice == 3:
        power = 7
        name = 'Double Punch'
    if attack_choice == 4:
        power = 12
        name = 'Double Kick'
    if attack_choice == 5:
        power = -2
        name = 'Stole HP and leach'
        
    return power,name

# %%
def fight_start(player1,player2):
    
    # Few var setup
    health1 = 100
    health2 = 100
    p1_c = 0
    p2_c = 0
    attack_power = 0
    attack_name = ''
    
    print('-----------LET THE BATTLE BEGIN-----------')
    time.sleep(2)
    
    # main game loop
    while True:
        
        
        
        # chooses on random which player attacks 
        player_choice = rd.randint(1, 2)
        
        attack_power,attack_name = attack(attack_power,attack_name)

        # Player attacking
        if player_choice == 1:
            health2 -= attack_power
            p1_c += 1
            print(f'----{player1} {attack_name}ed {player2}----')
            print(f'Status : {player1} = {health1} HP and {player2} = {health2} HP')

        if player_choice == 2:
            health1 -= attack_power
            p2_c += 1
            print(f'----{player2} {attack_name}ed {player1}----')
            print(f'Status : {player1} = {health1} HP and {player2} = {health2} HP')
        
        # Just a blank line and time break      
        print('')
        time.sleep(1.25)
        
        # Break the loop
        if ((health1 <= 0) or (health2 <= 0)):
            break
        
        
    
    # Game Results
    if health1 == 0:
        print(f'----{player2} Won----')
        print(f'{player2} attacked {p2_c} times')
        print(f'{player1} is Dead')
        print(f'{player1} attacked {p1_c} times')
    else:
        print(f'----{player1} Won----')
        print(f'{player1} attacked {p1_c} times')
        print(f'{player2} is Dead')
        print(f'{player2} attacked {p2_c} times')

# %%
# Main game area


# Getting player 1 and player 2 name
# player1 = input("Enter name for Player 1 : ")
player1 = 'Johny Kob'
# player2 = input("Enter name for Player 2 : ")
player2 = 'Samoa Rob'

fight_start(player1,player2)
# Out:
# -----------LET THE BATTLE BEGIN-----------
# ----Samoa Rob Puched Johny Kob----
# Status : Johny Kob = 95 HP and Samoa Rob = 100 HP
#
# ----Johny Kob Double Kicked Samoa Rob----
# Status : Johny Kob = 95 HP and Samoa Rob = 88 HP
#
# ----Samoa Rob Double Kicked Johny Kob----
# Status : Johny Kob = 83 HP and Samoa Rob = 88 HP
#
# ----Samoa Rob Stole HP and leached Johny Kob----
# Status : Johny Kob = 85 HP and Samoa Rob = 88 HP
#
# ----Johny Kob Kicked Samoa Rob----
# Status : Johny Kob = 85 HP and Samoa Rob = 78 HP
#
# ----Samoa Rob Double Kicked Johny Kob----
# Status : Johny Kob = 73 HP and Samoa Rob = 78 HP
#
# ----Johny Kob Double Kicked Samoa Rob----
# Status : Johny Kob = 73 HP and Samoa Rob = 66 HP
#
# ----Johny Kob Double Kicked Samoa Rob----
# Status : Johny Kob = 73 HP and Samoa Rob = 54 HP
#
# ----Samoa Rob Puched Johny Kob----
# Status : Johny Kob = 68 HP and Samoa Rob = 54 HP
#
# ----Samoa Rob Kicked Johny Kob----
# Status : Johny Kob = 58 HP and Samoa Rob = 54 HP
#
# ----Johny Kob Stole HP and leached Samoa Rob----
# Status : Johny Kob = 58 HP and Samoa Rob = 56 HP
#
# ----Samoa Rob Double Punched Johny Kob----
# Status : Johny Kob = 51 HP and Samoa Rob = 56 HP
#
# ----Samoa Rob Double Punched Johny Kob----
# Status : Johny Kob = 44 HP and Samoa Rob = 56 HP
#
# ----Samoa Rob Double Kicked Johny Kob----
# Status : Johny Kob = 32 HP and Samoa Rob = 56 HP
#
# ----Samoa Rob Puched Johny Kob----
# Status : Johny Kob = 27 HP and Samoa Rob = 56 HP
#
# ----Samoa Rob Puched Johny Kob----
# Status : Johny Kob = 22 HP and Samoa Rob = 56 HP
#
# ----Johny Kob Stole HP and leached Samoa Rob----
# Status : Johny Kob = 22 HP and Samoa Rob = 58 HP
#
# ----Samoa Rob Kicked Johny Kob----
# Status : Johny Kob = 12 HP and Samoa Rob = 58 HP
#
# ----Johny Kob Puched Samoa Rob----
# Status : Johny Kob = 12 HP and Samoa Rob = 53 HP
#
# ----Johny Kob Double Punched Samoa Rob----
# Status : Johny Kob = 12 HP and Samoa Rob = 46 HP
#
# ----Samoa Rob Double Kicked Johny Kob----
# Status : Johny Kob = 0 HP and Samoa Rob = 46 HP
#
# ----Samoa Rob Won----
# Samoa Rob attacked 13 times
# Johny Kob is Dead
# Johny Kob attacked 8 times
